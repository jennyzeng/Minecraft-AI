# %% [markdown]
# # TensorFlow Convolutional Neural Network for Image Classification

# %% [markdown]
# tutorial from
# [https://github.com/rdcolema/tensorflow-image-classification?files=1](https://github.com/rdcolema/tensorflow-image-classification?files=1)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import tensorflow as tf
import pandas as pd
import numpy as np
from sklearn.metrics import confusion_matrix
import time
from datetime import timedelta
import math
import dataset
import random

# %% [markdown]
# ## Configuration and Hyperparameters

# %%
# Convolutional Layer 1.
filter_size1 = 3 
num_filters1 = 32

# Convolutional Layer 2.
filter_size2 = 3
num_filters2 = 32

# Convolutional Layer 3.
filter_size3 = 3
num_filters3 = 64

# Fully-connected layer.
fc_size = 128             # Number of neurons in fully-connected layer.

# Number of color channels for the images: 1 channel for gray-scale.
num_channels = 3

# image dimensions (only squares for now)
img_height = 200
img_width = 320

# Size of image when flattened to a single dimension
img_size_flat = img_height * img_width * num_channels

# Tuple with height and width of images used to reshape arrays.
img_shape = (img_height, img_width)

# class info
classes = ['forest', 'mesa']
num_classes = len(classes)

# batch size
batch_size = 2

# validation split
validation_size = .2

# how long to wait after validation loss stops improving before terminating training
early_stopping = None  # use None if you don't want to implement early stoping

train_path = '/notebooks/Minecraft-AI/mc-data/forest_vs_mesa_train'
test_path = '/notebooks/Minecraft-AI/mc-data/forest_vs_mesa_test'
checkpoint_dir = "C:/Projects/playground/tensorflow/tf_image_clf/models/"

# %% [markdown]
# ## Load Data

# %%
data = dataset.read_train_sets(train_path, img_height, img_width, classes, validation_size=validation_size)
test_images, test_ids = dataset.read_test_set(test_path, img_height, img_width)
# Out:
# Reading training images
# Loading forest files (Index: 0)
# /notebooks/Minecraft-AI/mc-data/forest_vs_mesa_train/forest/*g
# ['/notebooks/Minecraft-AI/mc-data/forest_vs_mesa_train/forest/forest19.jpg', '/notebooks/Minecraft-AI/mc-data/forest_vs_mesa_train/forest/forest5.jpg', '/notebooks/Minecraft-AI/mc-data/forest_vs_mesa_train/forest/forest17.jpg', '/notebooks/Minecraft-AI/mc-data/forest_vs_mesa_train/forest/forest16.jpg', '/notebooks/Minecraft-AI/mc-data/forest_vs_mesa_train/forest/forest10.jpg', '/notebooks/Minecraft-AI/mc-data/forest_vs_mesa_train/forest/forest7.jpg', '/notebooks/Minecraft-AI/mc-data/forest_vs_mesa_train/forest/forest18.jpg', '/notebooks/Minecraft-AI/mc-data/forest_vs_mesa_train/forest/forest2.jpg', '/notebooks/Minecraft-AI/mc-data/forest_vs_mesa_train/forest/forest1.jpg', '/notebooks/Minecraft-AI/mc-data/forest_vs_mesa_train/forest/forest4.jpg', '/notebooks/Minecraft-AI/mc-data/forest_vs_mesa_train/forest/forest20.jpg', '/notebooks/Minecraft-AI/mc-data/forest_vs_mesa_train/forest/forest3.jpg', '/notebooks/Minecraft-AI/mc-data/forest_vs_mesa_train/forest/forest6.jpg', '/notebooks/Minecraft-AI/mc-data/forest_vs_mesa_train/forest/forest8.jpg', '/notebooks/Minecraft-AI/mc-data/forest_vs_mesa_train/forest/forest15.jpg', '/notebooks/Minecraft-AI/mc-data/forest_vs_mesa_train/forest/forest11.jpg', '/notebooks/Minecraft-AI/mc-data/forest_vs_mesa_train/forest/forest13.jpg']
# Loading mesa files (Index: 1)
# /notebooks/Minecraft-AI/mc-data/forest_vs_mesa_train/mesa/*g
# ['/notebooks/Minecraft-AI/mc-data/forest_vs_mesa_train/mesa/mesa13.jpg', '/notebooks/Minecraft-AI/mc-data/forest_vs_mesa_train/mesa/mesa16.jpg', '/notebooks/Minecraft-AI/mc-data/forest_vs_mesa_train/mesa/mesa1.jpg', '/notebooks/Minecraft-AI/mc-data/forest_vs_mesa_train/mesa/mesa5.jpg', '/notebooks/Minecraft-AI/mc-data/forest_vs_mesa_train/mesa/mesa18.jpg', '/notebooks/Minecraft-AI/mc-data/forest_vs_mesa_train/mesa/mesa20.jpg', '/notebooks/Minecraft-AI/mc-data/forest_vs_mesa_train/mesa/mesa2.jpg', '/notebooks/Minecraft-AI/mc-data/forest_vs_mesa_train/mesa/mesa19.jpg', '/notebooks/Minecraft-AI/mc-data/forest_vs_mesa_train/mesa/mesa9.jpg', '/notebooks/Minecraft-AI/mc-data/forest_vs_mesa_train/mesa/mesa15.jpg', '/notebooks/Minecraft-AI/mc-data/forest_vs_mesa_train/mesa/mesa3.jpg', '/notebooks/Minecraft-AI/mc-data/forest_vs_mesa_train/mesa/mesa4.jpg', '/notebooks/Minecraft-AI/mc-data/forest_vs_mesa_train/mesa/mesa7.jpg', '/notebooks/Minecraft-AI/mc-data/forest_vs_mesa_train/mesa/mesa12.jpg', '/notebooks/Minecraft-AI/mc-data/forest_vs_mesa_train/mesa/mesa8.jpg', '/notebooks/Minecraft-AI/mc-data/forest_vs_mesa_train/mesa/mesa6.jpg', '/notebooks/Minecraft-AI/mc-data/forest_vs_mesa_train/mesa/mesa10.jpg', '/notebooks/Minecraft-AI/mc-data/forest_vs_mesa_train/mesa/mesa17.jpg', '/notebooks/Minecraft-AI/mc-data/forest_vs_mesa_train/mesa/mesa11.jpg', '/notebooks/Minecraft-AI/mc-data/forest_vs_mesa_train/mesa/mesa14.jpg']
# /notebooks/Minecraft-AI/mc-data/forest_vs_mesa_test/*g
# ['/notebooks/Minecraft-AI/mc-data/forest_vs_mesa_test/forest21.jpg', '/notebooks/Minecraft-AI/mc-data/forest_vs_mesa_test/forest22.jpg', '/notebooks/Minecraft-AI/mc-data/forest_vs_mesa_test/forest23.jpg', '/notebooks/Minecraft-AI/mc-data/forest_vs_mesa_test/forest24.jpg', '/notebooks/Minecraft-AI/mc-data/forest_vs_mesa_test/mesa21.jpg', '/notebooks/Minecraft-AI/mc-data/forest_vs_mesa_test/mesa22.jpg', '/notebooks/Minecraft-AI/mc-data/forest_vs_mesa_test/mesa23.jpg', '/notebooks/Minecraft-AI/mc-data/forest_vs_mesa_test/mesa24.jpg']
# Reading test images

# %%
print("Size of:")
print("- Training-set:\t\t{}".format(len(data.train.labels)))
print("- Test-set:\t\t{}".format(len(test_images)))
print("- Validation-set:\t{}".format(len(data.valid.labels)))
# Out:
# Size of:
# - Training-set:		30
# - Test-set:		8
# - Validation-set:	7

# %% [markdown]
# ### Helper-function for plotting images

# %% [markdown]
# Function used to plot 9 images in a 3x3 grid (or fewer, depending on how many images are passed), and writing the true and predicted classes below each image.

# %%
def plot_images(images, cls_true, cls_pred=None):
    
    if len(images) == 0:
        print("no images to show")
        return 
    else:
        random_indices = random.sample(range(len(images)), min(len(images), 9))
        
        
    images, cls_true  = zip(*[(images[i], cls_true[i]) for i in random_indices])
    
    # Create figure with 3x3 sub-plots.
    fig, axes = plt.subplots(3, 3)
    fig.subplots_adjust(hspace=0.3, wspace=0.3)

    for i, ax in enumerate(axes.flat):
        # Plot image.
        ax.imshow(images[i].reshape(img_height, img_width, num_channels))

        # Show true and predicted classes.
        if cls_pred is None:
            xlabel = "True: {0}".format(cls_true[i])
        else:
            xlabel = "True: {0}, Pred: {1}".format(cls_true[i], cls_pred[i])

        # Show the classes as the label on the x-axis.
        ax.set_xlabel(xlabel)
        
        # Remove ticks from the plot.
        ax.set_xticks([])
        ax.set_yticks([])
    
    # Ensure the plot is shown correctly with multiple plots
    # in a single Notebook cell.
    plt.show()

# %% [markdown]
# ### Plot a few images to see if data is correct

# %%
# Get some random images and their labels from the train set.

images, cls_true  = data.train.images, data.train.cls

# Plot the images and labels using our helper-function above.
plot_images(images=images, cls_true=cls_true)

# %% [markdown]
# ## TensorFlow Graph
#
# The entire purpose of TensorFlow is to have a so-called computational graph that can be executed much more efficiently than if the same calculations were to be performed directly in Python. TensorFlow can be more efficient than NumPy because TensorFlow knows the entire computation graph that must be executed, while NumPy only knows the computation of a single mathematical operation at a time.
#
# TensorFlow can also automatically calculate the gradients that are needed to optimize the variables of the graph so as to make the model perform better. This is because the graph is a combination of simple mathematical expressions so the gradient of the entire graph can be calculated using the chain-rule for derivatives.
#
# A TensorFlow graph consists of the following parts which will be detailed below:
#
# * Placeholder variables used for inputting data to the graph.
# * Variables that are going to be optimized so as to make the convolutional network perform better.
# * The mathematical formulas for the convolutional network.
# * A cost measure that can be used to guide the optimization of the variables.
# * An optimization method which updates the variables.

# %% [markdown]
# ### Helper-functions for creating new variables

# %% [markdown]
# Functions for creating new TensorFlow variables in the given shape and initializing them with random values. Note that the initialization is not actually done at this point, it is merely being defined in the TensorFlow graph.

# %%
def new_weights(shape):
    return tf.Variable(tf.truncated_normal(shape, stddev=0.05))

# %%
def new_biases(length):
    return tf.Variable(tf.constant(0.05, shape=[length]))

# %% [markdown]
# ### Helper-function for creating a new Convolutional Layer

# %% [markdown]
# This function creates a new convolutional layer in the computational graph for TensorFlow. Nothing is actually calculated here, we are just adding the mathematical formulas to the TensorFlow graph.
#
# It is assumed that the input is a 4-dim tensor with the following dimensions:
#
# 1. Image number.
# 2. Y-axis of each image.
# 3. X-axis of each image.
# 4. Channels of each image.
#
# Note that the input channels may either be colour-channels, or it may be filter-channels if the input is produced from a previous convolutional layer.
#
# The output is another 4-dim tensor with the following dimensions:
#
# 1. Image number, same as input.
# 2. Y-axis of each image. If 2x2 pooling is used, then the height and width of the input images is divided by 2.
# 3. X-axis of each image. Ditto.
# 4. Channels produced by the convolutional filters.

# %%
def new_conv_layer(input,              # The previous layer.
                   num_input_channels, # Num. channels in prev. layer.
                   filter_size,        # Width and height of each filter.
                   num_filters,        # Number of filters.
                   use_pooling=True):  # Use 2x2 max-pooling.

    # Shape of the filter-weights for the convolution.
    # This format is determined by the TensorFlow API.
    shape = [filter_size, filter_size, num_input_channels, num_filters]

    # Create new weights aka. filters with the given shape.
    weights = new_weights(shape=shape)

    # Create new biases, one for each filter.
    biases = new_biases(length=num_filters)

    # Create the TensorFlow operation for convolution.
    # Note the strides are set to 1 in all dimensions.
    # The first and last stride must always be 1,
    # because the first is for the image-number and
    # the last is for the input-channel.
    # But e.g. strides=[1, 2, 2, 1] would mean that the filter
    # is moved 2 pixels across the x- and y-axis of the image.
    # The padding is set to 'SAME' which means the input image
    # is padded with zeroes so the size of the output is the same.
    layer = tf.nn.conv2d(input=input,
                         filter=weights,
                         strides=[1, 1, 1, 1],
                         padding='SAME')

    # Add the biases to the results of the convolution.
    # A bias-value is added to each filter-channel.
    layer += biases

    # Use pooling to down-sample the image resolution?
    if use_pooling:
        # This is 2x2 max-pooling, which means that we
        # consider 2x2 windows and select the largest value
        # in each window. Then we move 2 pixels to the next window.
        layer = tf.nn.max_pool(value=layer,
                               ksize=[1, 2, 2, 1],
                               strides=[1, 2, 2, 1],
                               padding='SAME')

    # Rectified Linear Unit (ReLU).
    # It calculates max(x, 0) for each input pixel x.
    # This adds some non-linearity to the formula and allows us
    # to learn more complicated functions.
    layer = tf.nn.relu(layer)

    # Note that ReLU is normally executed before the pooling,
    # but since relu(max_pool(x)) == max_pool(relu(x)) we can
    # save 75% of the relu-operations by max-pooling first.

    # We return both the resulting layer and the filter-weights
    # because we will plot the weights later.
    return layer, weights

# %% [markdown]
# ### Helper-function for flattening a layer
#
# A convolutional layer produces an output tensor with 4 dimensions. We will add fully-connected layers after the convolution layers, so we need to reduce the 4-dim tensor to 2-dim which can be used as input to the fully-connected layer.

# %%
def flatten_layer(layer):
    # Get the shape of the input layer.
    layer_shape = layer.get_shape()

    # The shape of the input layer is assumed to be:
    # layer_shape == [num_images, img_height, img_width, num_channels]

    # The number of features is: img_height * img_width * num_channels
    # We can use a function from TensorFlow to calculate this.
    num_features = layer_shape[1:4].num_elements()
    
    # Reshape the layer to [num_images, num_features].
    # Note that we just set the size of the second dimension
    # to num_features and the size of the first dimension to -1
    # which means the size in that dimension is calculated
    # so the total size of the tensor is unchanged from the reshaping.
    layer_flat = tf.reshape(layer, [-1, num_features])

    # The shape of the flattened layer is now:
    # [num_images, img_height * img_width * num_channels]

    # Return both the flattened layer and the number of features.
    return layer_flat, num_features

# %% [markdown]
# ### Helper-function for creating a new Fully-Connected Layer

# %% [markdown]
# This function creates a new fully-connected layer in the computational graph for TensorFlow. Nothing is actually calculated here, we are just adding the mathematical formulas to the TensorFlow graph.
#
# It is assumed that the input is a 2-dim tensor of shape `[num_images, num_inputs]`. The output is a 2-dim tensor of shape `[num_images, num_outputs]`.

# %%
def new_fc_layer(input,          # The previous layer.
                 num_inputs,     # Num. inputs from prev. layer.
                 num_outputs,    # Num. outputs.
                 use_relu=True): # Use Rectified Linear Unit (ReLU)?

    # Create new weights and biases.
    weights = new_weights(shape=[num_inputs, num_outputs])
    biases = new_biases(length=num_outputs)

    # Calculate the layer as the matrix multiplication of
    # the input and weights, and then add the bias-values.
    layer = tf.matmul(input, weights) + biases

    # Use ReLU?
    if use_relu:
        layer = tf.nn.relu(layer)

    return layer

# %% [markdown]
# ### Placeholder variables

# %% [markdown]
# Placeholder variables serve as the input to the TensorFlow computational graph that we may change each time we execute the graph. We call this feeding the placeholder variables and it is demonstrated further below.
#
# First we define the placeholder variable for the input images. This allows us to change the images that are input to the TensorFlow graph. This is a so-called tensor, which just means that it is a multi-dimensional vector or matrix. The data-type is set to `float32` and the shape is set to `[None, img_size_flat]`, where `None` means that the tensor may hold an arbitrary number of images with each image being a vector of length `img_size_flat`.

# %%
x = tf.placeholder("float", shape=[None, img_size_flat])

# %% [markdown]
# The convolutional layers expect `x` to be encoded as a 4-dim tensor so we have to reshape it so its shape is instead `[num_images, img_height, img_width, num_channels]`. Note that `img_height == img_width == img_size` and `num_images` can be inferred automatically by using -1 for the size of the first dimension. So the reshape operation is:

# %%
x_image = tf.reshape(x, [-1, img_height, img_width, num_channels])

# %% [markdown]
# Next we have the placeholder variable for the true labels associated with the images that were input in the placeholder variable `x`. The shape of this placeholder variable is `[None, num_classes]` which means it may hold an arbitrary number of labels and each label is a vector of length `num_classes`.

# %%
y_true = tf.placeholder("float", shape=[None, num_classes])

# %% [markdown]
# We could also have a placeholder variable for the class-number, but we will instead calculate it using argmax. Note that this is a TensorFlow operator so nothing is calculated at this point.

# %%
y_true_cls = tf.argmax(y_true, dimension=1)

# %% [markdown]
# ### Convolutional Layer 1
#
# Create the first convolutional layer. It takes `x_image` as input and creates `num_filters1` different filters, each having width and height equal to `filter_size1`. Finally we wish to down-sample the image so it is half the size by using 2x2 max-pooling.

# %%
layer_conv1, weights_conv1 = \
    new_conv_layer(input=x_image,
                   num_input_channels=num_channels,
                   filter_size=filter_size1,
                   num_filters=num_filters1,
                   use_pooling=True)

# %% [markdown]
# Check the shape of the tensor that will be output by the convolutional layer. It is (?, x, x, 16) which means that there is an arbitrary number of images (this is the ?), each image is x pixels wide and x pixels high, and there are 16 different channels, one channel for each of the filters.

# %%
layer_conv1
# Out:
# <tf.Tensor 'Relu:0' shape=(?, 100, 160, 32) dtype=float32>

# %% [markdown]
# ### Convolutional Layers 2 and 3
#
# Create the second and third convolutional layers, which take as input the output from the first and second convolutional layer respectively. The number of input channels corresponds to the number of filters in the previous convolutional layer.

# %%
layer_conv2, weights_conv2 = \
    new_conv_layer(input=layer_conv1,
                   num_input_channels=num_filters1,
                   filter_size=filter_size2,
                   num_filters=num_filters2,
                   use_pooling=True)

# %% [markdown]
# Check the shape of the tensor that will be output from this convolutional layer. The shape is (?, x, x, 36) where the ? again means that there is an arbitrary number of images, with each image having width and height of x pixels, and there are 36 channels, one for each filter.

# %%
layer_conv2
# Out:
# <tf.Tensor 'Relu_1:0' shape=(?, 50, 80, 32) dtype=float32>

# %%
layer_conv3, weights_conv3 = \
    new_conv_layer(input=layer_conv2,
                   num_input_channels=num_filters2,
                   filter_size=filter_size3,
                   num_filters=num_filters3,
                   use_pooling=True)

# %%
layer_conv3
# Out:
# <tf.Tensor 'Relu_2:0' shape=(?, 25, 40, 64) dtype=float32>

# %% [markdown]
# ### Flatten Layer
#
# The convolutional layers output 4-dim tensors. We now wish to use these as input in a fully-connected network, which requires for the tensors to be reshaped or flattened to 2-dim tensors.

# %%
layer_flat, num_features = flatten_layer(layer_conv3)

# %% [markdown]
# Check that the tensors now have shape (?, y) which means there's an arbitrary number of images which have been flattened to vectors of length y each. Note that y = (x from conv3) times (x from conv3) times 64.

# %%
layer_flat
# Out:
# <tf.Tensor 'Reshape_1:0' shape=(?, 64000) dtype=float32>

# %%
num_features
# Out:
# 64000

# %% [markdown]
# ### Fully-Connected Layer 1
#
# Add a fully-connected layer to the network. The input is the flattened layer from the previous convolution. The number of neurons or nodes in the fully-connected layer is `fc_size`. ReLU is used so we can learn non-linear relations.

# %%
layer_fc1 = new_fc_layer(input=layer_flat,
                         num_inputs=num_features,
                         num_outputs=fc_size,
                         use_relu=True)

# %% [markdown]
# Check that the output of the fully-connected layer is a tensor with shape (?, 128) where the ? means there is an arbitrary number of images and `fc_size` == 128.

# %%
layer_fc1
# Out:
# <tf.Tensor 'Relu_3:0' shape=(?, 128) dtype=float32>

# %% [markdown]
# ### Fully-Connected Layer 2
#
# Add another fully-connected layer that outputs vectors of length num_classes for determining which of the classes the input image belongs to. Note that ReLU is not used in this layer.

# %%
layer_fc2 = new_fc_layer(input=layer_fc1,
                         num_inputs=fc_size,
                         num_outputs=num_classes,
                         use_relu=False)

# %%
layer_fc2
# Out:
# <tf.Tensor 'add_4:0' shape=(?, 2) dtype=float32>

# %% [markdown]
# ### Predicted Class

# %% [markdown]
# The second fully-connected layer estimates how likely it is that the input image belongs to each of the 10 classes. However, these estimates are a bit rough and difficult to interpret because the numbers may be very small or large, so we want to normalize them so that each element is limited between zero and one and the 10 elements sum to one. This is calculated using the so-called softmax function and the result is stored in `y_pred`.

# %%
y_pred = tf.nn.softmax(layer_fc2)

# %% [markdown]
# The class-number is the index of the largest element.

# %%
y_pred_cls = tf.argmax(y_pred, dimension=1)

# %% [markdown]
# ### Cost-function to be optimized

# %% [markdown]
# To make the model better at classifying the input images, we must somehow change the variables for all the network layers. To do this we first need to know how well the model currently performs by comparing the predicted output of the model `y_pred` to the desired output `y_true`.
#
# The cross-entropy is a performance measure used in classification. The cross-entropy is a continuous function that is always positive and if the predicted output of the model exactly matches the desired output then the cross-entropy equals zero. The goal of optimization is therefore to minimize the cross-entropy so it gets as close to zero as possible by changing the variables of the network layers.
#
# TensorFlow has a built-in function for calculating the cross-entropy. Note that the function calculates the softmax internally so we must use the output of `layer_fc2` directly rather than `y_pred` which has already had the softmax applied.

# %%
cross_entropy = tf.nn.softmax_cross_entropy_with_logits(logits=layer_fc2,
                                                        labels=y_true)

# %% [markdown]
# We have now calculated the cross-entropy for each of the image classifications so we have a measure of how well the model performs on each image individually. But in order to use the cross-entropy to guide the optimization of the model's variables we need a single scalar value, so we simply take the average of the cross-entropy for all the image classifications.

# %%
cost = tf.reduce_mean(cross_entropy)

# %% [markdown]
# ### Optimization Method

# %% [markdown]
# Now that we have a cost measure that must be minimized, we can then create an optimizer. In this case it is the `AdamOptimizer` which is an advanced form of Gradient Descent.
#
# Note that optimization is not performed at this point. In fact, nothing is calculated at all, we just add the optimizer-object to the TensorFlow graph for later execution.

# %%
optimizer = tf.train.AdamOptimizer(learning_rate=1e-4).minimize(cost)

# %% [markdown]
# ### Performance Measures

# %% [markdown]
# We need a few more performance measures to display the progress to the user.
#
# This is a vector of booleans whether the predicted class equals the true class of each image.

# %%
correct_prediction = tf.equal(y_pred_cls, y_true_cls)

# %% [markdown]
# This calculates the classification accuracy by first type-casting the vector of booleans to floats, so that False becomes 0 and True becomes 1, and then calculating the average of these numbers.

# %%
accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))

# %% [markdown]
# ## TensorFlow Run

# %% [markdown]
# ### Create TensorFlow session
#
# Once the TensorFlow graph has been created, we have to create a TensorFlow session which is used to execute the graph.

# %%
session = tf.Session()

# %% [markdown]
# ### Initialize variables
#
# The variables for `weights` and `biases` must be initialized before we start optimizing them.

# %%
session.run(tf.global_variables_initializer())

# %% [markdown]
# ### Helper-function to perform optimization iterations

# %% [markdown]
# It takes a long time to calculate the gradient of the model using the entirety of a large dataset
# . We therefore only use a small batch of images in each iteration of the optimizer.
#
# If your computer crashes or becomes very slow because you run out of RAM, then you may try and lower this number, but you may then need to perform more optimization iterations.

# %%
train_batch_size = batch_size

# %%
def print_progress(epoch, feed_dict_train, feed_dict_validate, val_loss):
    # Calculate the accuracy on the training-set.
    acc = session.run(accuracy, feed_dict=feed_dict_train)
    val_acc = session.run(accuracy, feed_dict=feed_dict_validate)
    msg = "Epoch {0} --- Training Accuracy: {1:>6.1%}, Validation Accuracy: {2:>6.1%}, Validation Loss: {3:.3f}"
    print(msg.format(epoch + 1, acc, val_acc, val_loss))

# %% [markdown]
# Function for performing a number of optimization iterations so as to gradually improve the variables of the network layers. In each iteration, a new batch of data is selected from the training-set and then TensorFlow executes the optimizer using those training samples.  The progress is printed every 100 iterations.

# %%
# Counter for total number of iterations performed so far.
total_iterations = 0

def optimize(num_iterations):
    # Ensure we update the global variable rather than a local copy.
    global total_iterations

    # Start-time used for printing time-usage below.
    start_time = time.time()
    
    best_val_loss = float("inf")
    patience = 0

    for i in range(total_iterations,
                   total_iterations + num_iterations):

        # Get a batch of training examples.
        # x_batch now holds a batch of images and
        # y_true_batch are the true labels for those images.
        x_batch, y_true_batch, _, cls_batch = data.train.next_batch(train_batch_size)
        x_valid_batch, y_valid_batch, _, valid_cls_batch = data.valid.next_batch(train_batch_size)

        # Convert shape from [num examples, rows, columns, depth]
        # to [num examples, flattened image shape]

        x_batch = x_batch.reshape(train_batch_size, img_size_flat)
        x_valid_batch = x_valid_batch.reshape(train_batch_size, img_size_flat)

        # Put the batch into a dict with the proper names
        # for placeholder variables in the TensorFlow graph.
        feed_dict_train = {x: x_batch,
                           y_true: y_true_batch}
        return x_batch
        feed_dict_validate = {x: x_valid_batch,
                              y_true: y_valid_batch}

        # Run the optimizer using this batch of training data.
        # TensorFlow assigns the variables in feed_dict_train
        # to the placeholder variables and then runs the optimizer.
        session.run(optimizer, feed_dict=feed_dict_train)
        

        # Print status at end of each epoch (defined as full pass through training dataset).
        if i % int(data.train.num_examples/batch_size) == 0: 
            val_loss = session.run(cost, feed_dict=feed_dict_validate)
            epoch = int(i / int(data.train.num_examples/batch_size))
            
            print_progress(epoch, feed_dict_train, feed_dict_validate, val_loss)
            
            if early_stopping:    
                if val_loss < best_val_loss:
                    best_val_loss = val_loss
                    patience = 0
                else:
                    patience += 1

                if patience == early_stopping:
                    break

    # Update the total number of iterations performed.
    total_iterations += num_iterations

    # Ending time.
    end_time = time.time()

    # Difference between start and end-times.
    time_dif = end_time - start_time

    # Print the time-usage.
    print("Time elapsed: " + str(timedelta(seconds=int(round(time_dif)))))

# %% [markdown]
# ### Helper-function to plot example errors

# %% [markdown]
# Function for plotting examples of images from the test-set that have been mis-classified.

# %%
def plot_example_errors(cls_pred, correct):
    # cls_pred is an array of the predicted class-number for
    # all images in the test-set.

    # correct is a boolean array whether the predicted class
    # is equal to the true class for each image in the test-set.

    # Negate the boolean array.
    incorrect = (correct == False)
    
    # Get the images from the test-set that have been
    # incorrectly classified.
    images = data.valid.images[incorrect]
    
    # Get the predicted classes for those images.
    cls_pred = cls_pred[incorrect]

    # Get the true classes for those images.
    cls_true = data.valid.cls[incorrect]
    
    # Plot the first 9 images.
    plot_images(images=images[0:9],
                cls_true=cls_true[0:9],
                cls_pred=cls_pred[0:9])

# %% [markdown]
# ### Helper-function to plot confusion matrix

# %%
def plot_confusion_matrix(cls_pred):
    # cls_pred is an array of the predicted class-number for
    # all images in the test-set.

    # Get the true classifications for the test-set.
    cls_true = data.valid.cls
    
    # Get the confusion matrix using sklearn.
    cm = confusion_matrix(y_true=cls_true,
                          y_pred=cls_pred)

    # Print the confusion matrix as text.
    print(cm)

    # Plot the confusion matrix as an image.
    plt.matshow(cm)

    # Make various adjustments to the plot.
    plt.colorbar()
    tick_marks = np.arange(num_classes)
    plt.xticks(tick_marks, range(num_classes))
    plt.yticks(tick_marks, range(num_classes))
    plt.xlabel('Predicted')
    plt.ylabel('True')

    # Ensure the plot is shown correctly with multiple plots
    # in a single Notebook cell.
    plt.show()

# %% [markdown]
# ### Helper-function for showing the performance

# %% [markdown]
# Function for printing the classification accuracy on the test-set.
#
# It takes a while to compute the classification for all the images in the test-set, that's why the results are re-used by calling the above functions directly from this function, so the classifications don't have to be recalculated by each function.
#
# Note that this function can use a lot of computer memory, which is why the test-set is split into smaller batches. If you have little RAM in your computer and it crashes, then you can try and lower the batch-size.

# %%
def print_validation_accuracy(show_example_errors=False,
                        show_confusion_matrix=False):
    
    x = tf.placeholder(tf.float64, shape=[2, img_size_flat], name='x')
    y_true = tf.placeholder(tf.float64, shape=[2, num_classes], name='y_true')

    # Number of images in the test-set.
    num_test = len(data.valid.images)

    # Allocate an array for the predicted classes which
    # will be calculated in batches and filled into this array.
    cls_pred = np.zeros(shape=num_test, dtype=np.int)

    # Now calculate the predicted classes for the batches.
    # We will just iterate through all the batches.
    # There might be a more clever and Pythonic way of doing this.

    # The starting index for the next batch is denoted i.
    i = 0

    while i < num_test:
        # The ending index for the next batch is denoted j.
        j = min(i + batch_size, num_test)

        # Get the images from the test-set between index i and j.
        images = data.valid.images[i:j, :].reshape(batch_size, img_size_flat)
        

        # Get the associated labels.
        labels = data.valid.labels[i:j, :]

        # Create a feed-dict with these images and labels.
        feed_dict = {x: images,
                     y_true: labels}

        # Calculate the predicted class using TensorFlow.
        cls_pred[i:j] = session.run(y_pred_cls, feed_dict=feed_dict)

        # Set the start-index for the next batch to the
        # end-index of the current batch.
        i = j

    cls_true = np.array(data.valid.cls)
    cls_pred = np.array([classes[x] for x in cls_pred]) 

    # Create a boolean array whether each image is correctly classified.
    correct = (cls_true == cls_pred)

    # Calculate the number of correctly classified images.
    # When summing a boolean array, False means 0 and True means 1.
    correct_sum = correct.sum()

    # Classification accuracy is the number of correctly classified
    # images divided by the total number of images in the test-set.
    acc = float(correct_sum) / num_test

    # Print the accuracy.
    msg = "Accuracy on Test-Set: {0:.1%} ({1} / {2})"
    print(msg.format(acc, correct_sum, num_test))

    # Plot some examples of mis-classifications, if desired.
    if show_example_errors:
        print("Example errors:")
        plot_example_errors(cls_pred=cls_pred, correct=correct)

    # Plot the confusion matrix, if desired.
    if show_confusion_matrix:
        print("Confusion Matrix:")
        plot_confusion_matrix(cls_pred=cls_pred)

# %% [markdown]
# ## Performance after 1 optimization iteration

# %%
# Out[9]:
# <tf.Tensor 'Placeholder_4:0' shape=(?, 2) dtype=float32>

# %%
x
# Out:
# <tf.Tensor 'Placeholder_9:0' shape=(?, 192000) dtype=float32>

# %%
bla = optimize(num_iterations=1)
# print_validation_accuracy()

# %%
bla
# Out:
# array([[ 0.80784321,  0.57254905,  0.45490199, ...,  0.        ,
#          0.03137255,  0.        ],
#        [ 0.81176478,  0.59607846,  0.41960788, ...,  0.10196079,
#          0.20784315,  0.4039216 ]], dtype=float32)

# %% [markdown]
# ## Performance after 100 optimization iterations
#
# After 100 optimization iterations, the model should have significantly improved its classification accuracy.

# %%
optimize(num_iterations=99)  # We already performed 1 iteration above.
# Out:
# Epoch 2 --- Training Accuracy: 100.0%, Validation Accuracy:  50.0%, Validation Loss: 0.735
# Epoch 3 --- Training Accuracy: 100.0%, Validation Accuracy:  50.0%, Validation Loss: 0.564
# Epoch 4 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.318
# Epoch 5 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.091
# Epoch 6 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.067
# Epoch 7 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.033
# Time elapsed: 0:00:02

# %%
#print_validation_accuracy(show_example_errors=True)

# %% [markdown]
# ## Performance after 1000 optimization iterations

# %%
optimize(num_iterations=900)  # We performed 100 iterations above.
# Out:
# Epoch 15 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.001
# Epoch 16 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.001
# Epoch 17 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 18 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 19 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 20 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 21 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 22 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 23 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 24 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 25 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 26 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 27 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 28 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 29 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 30 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 31 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 32 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 33 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 34 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 35 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 36 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 37 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 38 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 39 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 40 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 41 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 42 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 43 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 44 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 45 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 46 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 47 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 48 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 49 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 50 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 51 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 52 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 53 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 54 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 55 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 56 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 57 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 58 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 59 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 60 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 61 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 62 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 63 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 64 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 65 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 66 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 67 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 68 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 69 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 70 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 71 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 72 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 73 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 74 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Time elapsed: 0:00:20

# %%
print_validation_accuracy(show_example_errors=True)
# Out:
# ValueErrorTraceback (most recent call last)
# <ipython-input-56-ad470030e9e7> in <module>()
# ----> 1 print_validation_accuracy(show_example_errors=True)
#
# <ipython-input-49-ad0bb1890f01> in print_validation_accuracy(show_example_errors, show_confusion_matrix)
#      21
#      22         # Get the images from the test-set between index i and j.
# ---> 23         images = data.valid.images[i:j, :].reshape(batch_size, img_size_flat)
#      24
#      25
#
# ValueError: cannot reshape array of size 1344000 into shape (10,192000)

# %% [markdown]
# ## Performance after 10,000 optimization iterations

# %%
optimize(num_iterations=9000) # We performed 1000 iterations above.
# Out:
# Epoch 75 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 76 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 77 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 78 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 79 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 80 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 81 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 82 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 83 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 84 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 85 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 86 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 87 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 88 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 89 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 90 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 91 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 92 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 93 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 94 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 95 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 96 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 97 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 98 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 99 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 100 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 101 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 102 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 103 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 104 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 105 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 106 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 107 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 108 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 109 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 110 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 111 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 112 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 113 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 114 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 115 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 116 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 117 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 118 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 119 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 120 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 121 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 122 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 123 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 124 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 125 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 126 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 127 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 128 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 129 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 130 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 131 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 132 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 133 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 134 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 135 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 136 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 137 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 138 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 139 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 140 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 141 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 142 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 143 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 144 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 145 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 146 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 147 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 148 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 149 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 150 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 151 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 152 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 153 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 154 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 155 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 156 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 157 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 158 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 159 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 160 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 161 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 162 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 163 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 164 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 165 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 166 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 167 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 168 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 169 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 170 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 171 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 172 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 173 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 174 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 175 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 176 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 177 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 178 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 179 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 180 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 181 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 182 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 183 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 184 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 185 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 186 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 187 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 188 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 189 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 190 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 191 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 192 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 193 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 194 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 195 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 196 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 197 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 198 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 199 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 200 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 201 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 202 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 203 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 204 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 205 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 206 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 207 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 208 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 209 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 210 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 211 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 212 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 213 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 214 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 215 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 216 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 217 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 218 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 219 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 220 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 221 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 222 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 223 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 224 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 225 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 226 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 227 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 228 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 229 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 230 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 231 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 232 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 233 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 234 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 235 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 236 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 237 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 238 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 239 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 240 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 241 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 242 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 243 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 244 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 245 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 246 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 247 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 248 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 249 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 250 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 251 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 252 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 253 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 254 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 255 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 256 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 257 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 258 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 259 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 260 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 261 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 262 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 263 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 264 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 265 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 266 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 267 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 268 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 269 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 270 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 271 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 272 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 273 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 274 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 275 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 276 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 277 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 278 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 279 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 280 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 281 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 282 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 283 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 284 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 285 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 286 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 287 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 288 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 289 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 290 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 291 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 292 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 293 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 294 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 295 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 296 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 297 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 298 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 299 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 300 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 301 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 302 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 303 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 304 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 305 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 306 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 307 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 308 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 309 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 310 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 311 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 312 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 313 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 314 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 315 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 316 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 317 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 318 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 319 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 320 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 321 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 322 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 323 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 324 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 325 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 326 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 327 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 328 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 329 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 330 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 331 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 332 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 333 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 334 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 335 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 336 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 337 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 338 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 339 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 340 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 341 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 342 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 343 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 344 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 345 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 346 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 347 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 348 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 349 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 350 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 351 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 352 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 353 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 354 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 355 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 356 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 357 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 358 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 359 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 360 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 361 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 362 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 363 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 364 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 365 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 366 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 367 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 368 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 369 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 370 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 371 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 372 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 373 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 374 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 375 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 376 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 377 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 378 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 379 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 380 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 381 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 382 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 383 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 384 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 385 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 386 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 387 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 388 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 389 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 390 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 391 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 392 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 393 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 394 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 395 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 396 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 397 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 398 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 399 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 400 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 401 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 402 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 403 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 404 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 405 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 406 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 407 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 408 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 409 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 410 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 411 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 412 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 413 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 414 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 415 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 416 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 417 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 418 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 419 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 420 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 421 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 422 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 423 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 424 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 425 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 426 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 427 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 428 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 429 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 430 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 431 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 432 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 433 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 434 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 435 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 436 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 437 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 438 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 439 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 440 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 441 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 442 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 443 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 444 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 445 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 446 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 447 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 448 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 449 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 450 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 451 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 452 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 453 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 454 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 455 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 456 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 457 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 458 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 459 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 460 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 461 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 462 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 463 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 464 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 465 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 466 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 467 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 468 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 469 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 470 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 471 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 472 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 473 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 474 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 475 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 476 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 477 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 478 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 479 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 480 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 481 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 482 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 483 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 484 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 485 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 486 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 487 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 488 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 489 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 490 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 491 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 492 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 493 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 494 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 495 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 496 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 497 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 498 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 499 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 500 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 501 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 502 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 503 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 504 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 505 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 506 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 507 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 508 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 509 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 510 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 511 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 512 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 513 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 514 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 515 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 516 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 517 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 518 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 519 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 520 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 521 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 522 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 523 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 524 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 525 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 526 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 527 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 528 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 529 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 530 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 531 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 532 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 533 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 534 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 535 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 536 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 537 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 538 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 539 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 540 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 541 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 542 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 543 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 544 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 545 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 546 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 547 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 548 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 549 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 550 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 551 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 552 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 553 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 554 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 555 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 556 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 557 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 558 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 559 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 560 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 561 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 562 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 563 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 564 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 565 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 566 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 567 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 568 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 569 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 570 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 571 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 572 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 573 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 574 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 575 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 576 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 577 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 578 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 579 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 580 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 581 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 582 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 583 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 584 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 585 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 586 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 587 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 588 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 589 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 590 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 591 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 592 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 593 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 594 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 595 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 596 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 597 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 598 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 599 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 600 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 601 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 602 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 603 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 604 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 605 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 606 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 607 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 608 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 609 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 610 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 611 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 612 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 613 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 614 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 615 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 616 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 617 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 618 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 619 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 620 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 621 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 622 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 623 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 624 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 625 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 626 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 627 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 628 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 629 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 630 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 631 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 632 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 633 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 634 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 635 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 636 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 637 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 638 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 639 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 640 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 641 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 642 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 643 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 644 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 645 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 646 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 647 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 648 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 649 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 650 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 651 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 652 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 653 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 654 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 655 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 656 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 657 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 658 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 659 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 660 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 661 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 662 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 663 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 664 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 665 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 666 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 667 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 668 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 669 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 670 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 671 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000

# %%
print_validation_accuracy(show_example_errors=True,
                    show_confusion_matrix=True)
# Out:
# UnboundLocalErrorTraceback (most recent call last)
# <ipython-input-48-7b08ae4cee52> in <module>()
#       1 print_validation_accuracy(show_example_errors=True,
# ----> 2                     show_confusion_matrix=True)
#
# <ipython-input-43-ad0bb1890f01> in print_validation_accuracy(show_example_errors, show_confusion_matrix)
#      28
#      29         # Create a feed-dict with these images and labels.
# ---> 30         feed_dict = {x: images,
#      31                      y_true: labels}
#      32
#
# UnboundLocalError: local variable 'x' referenced before assignment

# %% [markdown]
# ## Visualization of Weights and Layers
#
# In trying to understand why the convolutional neural network can recognize images, we will now visualize the weights of the convolutional filters and the resulting output images.

# %% [markdown]
# ### Helper-function for plotting convolutional weights

# %%
def plot_conv_weights(weights, input_channel=0):
    # Assume weights are TensorFlow ops for 4-dim variables
    # e.g. weights_conv1 or weights_conv2.
    
    # Retrieve the values of the weight-variables from TensorFlow.
    # A feed-dict is not necessary because nothing is calculated.
    w = session.run(weights)

    # Get the lowest and highest values for the weights.
    # This is used to correct the colour intensity across
    # the images so they can be compared with each other.
    w_min = np.min(w)
    w_max = np.max(w)

    # Number of filters used in the conv. layer.
    num_filters = w.shape[3]

    # Number of grids to plot.
    # Rounded-up, square-root of the number of filters.
    num_grids = math.ceil(math.sqrt(num_filters))
    
    # Create figure with a grid of sub-plots.
    fig, axes = plt.subplots(num_grids, num_grids)

    # Plot all the filter-weights.
    for i, ax in enumerate(axes.flat):
        # Only plot the valid filter-weights.
        if i<num_filters:
            # Get the weights for the i'th filter of the input channel.
            # See new_conv_layer() for details on the format
            # of this 4-dim tensor.
            img = w[:, :, input_channel, i]

            # Plot image.
            ax.imshow(img, vmin=w_min, vmax=w_max,
                      interpolation='nearest', cmap='seismic')
        
        # Remove ticks from the plot.
        ax.set_xticks([])
        ax.set_yticks([])
    
    # Ensure the plot is shown correctly with multiple plots
    # in a single Notebook cell.
    plt.show()

# %% [markdown]
# ### Helper-function for plotting the output of a convolutional layer

# %%
def plot_conv_layer(layer, image):
    # Assume layer is a TensorFlow op that outputs a 4-dim tensor
    # which is the output of a convolutional layer,
    # e.g. layer_conv1 or layer_conv2.
    
    image = image.reshape(img_size_flat)

    # Create a feed-dict containing just one image.
    # Note that we don't need to feed y_true because it is
    # not used in this calculation.
    feed_dict = {x: [image]}

    # Calculate and retrieve the output values of the layer
    # when inputting that image.
    values = session.run(layer, feed_dict=feed_dict)

    # Number of filters used in the conv. layer.
    num_filters = values.shape[3]

    # Number of grids to plot.
    # Rounded-up, square-root of the number of filters.
    num_grids = math.ceil(math.sqrt(num_filters))
    
    # Create figure with a grid of sub-plots.
    fig, axes = plt.subplots(num_grids, num_grids)

    # Plot the output images of all the filters.
    for i, ax in enumerate(axes.flat):
        # Only plot the images for valid filters.
        if i<num_filters:
            # Get the output image of using the i'th filter.
            # See new_conv_layer() for details on the format
            # of this 4-dim tensor.
            img = values[0, :, :, i]

            # Plot image.
            ax.imshow(img, interpolation='nearest', cmap='binary')
        
        # Remove ticks from the plot.
        ax.set_xticks([])
        ax.set_yticks([])
    
    # Ensure the plot is shown correctly with multiple plots
    # in a single Notebook cell.
    plt.show()

# %% [markdown]
# ### Input Images

# %% [markdown]
# Helper-function for plotting an image.

# %%
def plot_image(image):
    plt.imshow(image.reshape(img_height, img_width, num_channels),
               interpolation='nearest')
    plt.show()

# %% [markdown]
# Plot an image from the test-set which will be used as an example below.

# %%
image1 = test_images[0]
plot_image(image1)

# %% [markdown]
# Plot another example image from the test-set.

# %%
image2 = test_images[5]
plot_image(image2)

# %% [markdown]
# ### Convolution Layer 1

# %% [markdown]
# Now plot the filter-weights for the first convolutional layer.
#
# Note that positive weights are red and negative weights are blue.

# %%
plot_conv_weights(weights=weights_conv1)
# Out:
# TypeErrorTraceback (most recent call last)
# <ipython-input-116-dbad5c764354> in <module>()
# ----> 1 plot_conv_weights(weights=weights_conv1)
#
# <ipython-input-106-8350f1417465> in plot_conv_weights(weights, input_channel)
#      21
#      22     # Create figure with a grid of sub-plots.
# ---> 23     fig, axes = plt.subplots(num_grids, num_grids)
#      24
#      25     # Plot all the filter-weights.
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/pyplot.pyc in subplots(nrows, ncols, sharex, sharey, squeeze, subplot_kw, gridspec_kw, **fig_kw)
#    1207     # so we can just append subplots upon creation, and then
#    1208     nplots = nrows*ncols
# -> 1209     axarr = np.empty(nplots, dtype=object)
#    1210
#    1211     # Create first subplot separately, so we can share it if requested
#
# TypeError: 'float' object cannot be interpreted as an index

# %% [markdown]
# Applying each of these convolutional filters to the first input image gives the following output images, which are then used as input to the second convolutional layer. Note that these images are down-sampled to about half the resolution of the original input image.

# %%
plot_conv_layer(layer=layer_conv1, image=image1)
# Out:
# TypeErrorTraceback (most recent call last)
# <ipython-input-117-6a9d1c419864> in <module>()
# ----> 1 plot_conv_layer(layer=layer_conv1, image=image1)
#
# <ipython-input-109-5ab73fcdbee1> in plot_conv_layer(layer, image)
#      23
#      24     # Create figure with a grid of sub-plots.
# ---> 25     fig, axes = plt.subplots(num_grids, num_grids)
#      26
#      27     # Plot the output images of all the filters.
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/pyplot.pyc in subplots(nrows, ncols, sharex, sharey, squeeze, subplot_kw, gridspec_kw, **fig_kw)
#    1207     # so we can just append subplots upon creation, and then
#    1208     nplots = nrows*ncols
# -> 1209     axarr = np.empty(nplots, dtype=object)
#    1210
#    1211     # Create first subplot separately, so we can share it if requested
#
# TypeError: 'float' object cannot be interpreted as an index

# %% [markdown]
# The following images are the results of applying the convolutional filters to the second image.

# %%
plot_conv_layer(layer=layer_conv1, image=image2)
# Out:
# TypeErrorTraceback (most recent call last)
# <ipython-input-118-cc5db73b800e> in <module>()
# ----> 1 plot_conv_layer(layer=layer_conv1, image=image2)
#
# <ipython-input-109-5ab73fcdbee1> in plot_conv_layer(layer, image)
#      23
#      24     # Create figure with a grid of sub-plots.
# ---> 25     fig, axes = plt.subplots(num_grids, num_grids)
#      26
#      27     # Plot the output images of all the filters.
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/pyplot.pyc in subplots(nrows, ncols, sharex, sharey, squeeze, subplot_kw, gridspec_kw, **fig_kw)
#    1207     # so we can just append subplots upon creation, and then
#    1208     nplots = nrows*ncols
# -> 1209     axarr = np.empty(nplots, dtype=object)
#    1210
#    1211     # Create first subplot separately, so we can share it if requested
#
# TypeError: 'float' object cannot be interpreted as an index

# %% [markdown]
# ### Convolution Layer 2

# %% [markdown]
# Now plot the filter-weights for the second convolutional layer.
#
# There are 16 output channels from the first conv-layer, which means there are 16 input channels to the second conv-layer. The second conv-layer has a set of filter-weights for each of its input channels. We start by plotting the filter-weigths for the first channel.
#
# Note again that positive weights are red and negative weights are blue.

# %%
plot_conv_weights(weights=weights_conv2, input_channel=0)
# Out:
# TypeErrorTraceback (most recent call last)
# <ipython-input-119-6c465cc61c69> in <module>()
# ----> 1 plot_conv_weights(weights=weights_conv2, input_channel=0)
#
# <ipython-input-106-8350f1417465> in plot_conv_weights(weights, input_channel)
#      21
#      22     # Create figure with a grid of sub-plots.
# ---> 23     fig, axes = plt.subplots(num_grids, num_grids)
#      24
#      25     # Plot all the filter-weights.
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/pyplot.pyc in subplots(nrows, ncols, sharex, sharey, squeeze, subplot_kw, gridspec_kw, **fig_kw)
#    1207     # so we can just append subplots upon creation, and then
#    1208     nplots = nrows*ncols
# -> 1209     axarr = np.empty(nplots, dtype=object)
#    1210
#    1211     # Create first subplot separately, so we can share it if requested
#
# TypeError: 'float' object cannot be interpreted as an index

# %% [markdown]
# There are 16 input channels to the second convolutional layer, so we can make another 15 plots of filter-weights like this. We just make one more with the filter-weights for the second channel.

# %%
plot_conv_weights(weights=weights_conv2, input_channel=1)

# %% [markdown]
# It can be difficult to understand and keep track of how these filters are applied because of the high dimensionality.
#
# Applying these convolutional filters to the images that were ouput from the first conv-layer gives the following images.
#
# Note that these are down-sampled yet again to half the resolution of the images from the first conv-layer.

# %%
plot_conv_layer(layer=layer_conv2, image=image1)

# %% [markdown]
# And these are the results of applying the filter-weights to the second image.

# %%
plot_conv_layer(layer=layer_conv2, image=image2)

# %% [markdown]
# ### Write Test Predictions to CSV

# %%
# def write_predictions(ims, ids):
#     ims = ims.reshape(ims.shape[0], img_size_flat)
#     preds = session.run(y_pred, feed_dict={x: ims})
#     result = pd.DataFrame(preds, columns=classes)
#     result.loc[:, 'id'] = pd.Series(ids, index=result.index)
#     pred_file = 'predictions.csv'
#     result.to_csv(pred_file, index=False)

# write_predictions(test_images, test_ids)

# %% [markdown]
# ### Close TensorFlow Session

# %% [markdown]
# We are now done using TensorFlow, so we close the session to release its resources.

# %%
session.close()
